# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
def acf_pacf(x, qtd_lag):
    fig = plt.figure(figsize=(16,10))
    ax1 = fig.add_subplot(221)
    fig = sm.graphics.tsa.plot_acf(x, lags=qtd_lag, ax=ax1)
    ax2 = fig.add_subplot(222)
    fig = sm.graphics.tsa.plot_pacf(x, lags=qtd_lag, ax=ax2)
    plt.show()

# %%
sudeste_path = '../data/parquet/regiao/SUL.parquet'
df = pd.read_parquet(sudeste_path)
df.head()
# Out:
#              Nome do RCBP       Sexo Data de Nascimento  Idade Raca/Cor  \
# 360524      RCBP CURITIBA  MASCULINO         28/09/1933   62.0   BRANCO
# 494715  RCBP PORTO ALEGRE   FEMININO         19/08/1927   65.0   BRANCO
# 494716  RCBP PORTO ALEGRE   FEMININO         17/01/1934   59.0   BRANCO
# 494717  RCBP PORTO ALEGRE   FEMININO         24/10/1939   54.0   BRANCO
# 494718  RCBP PORTO ALEGRE  MASCULINO         09/05/1920   72.0   BRANCO
#
#         Nacionalidade Naturalidade Estado   Naturalidade  \
# 360524         BRASIL       Não informado           None
# 494715         BRASIL       Não informado  Não Informado
# 494716         BRASIL   RIO GRANDE DO SUL           None
# 494717  Não informado       Não informado  Não Informado
# 494718  Não informado       Não informado  Não Informado
#
#                      Grau de Instrução    Estado Civil  ...  Lateralidade  \
# 360524                  SEM INFORMAÇÃO  SEM INFORMAÇÃO  ...          None
# 494715                  SEM INFORMAÇÃO           VIÚVO  ...          None
# 494716  FUNDAMENTAL II (5ª A 8ª SÉRIE)  SEM INFORMAÇÃO  ...          None
# 494717                  SEM INFORMAÇÃO        SOLTEIRO  ...          None
# 494718                  SEM INFORMAÇÃO  SEM INFORMAÇÃO  ...          None
#
#        Estadiamento  TNM Status Vital   Tipo do Obito Data do Óbito  \
# 360524          nan  nan         None          CÂNCER    21/04/1998
# 494715          nan  nan         None          CÂNCER    12/05/2018
# 494716          nan  nan         None  SEM INFORMAÇÃO    25/09/1994
# 494717          nan  nan         None  SEM INFORMAÇÃO    28/04/1994
# 494718          nan  nan         None          CÂNCER    26/06/2019
#
#        Data de Último Contato  Data de Diagnostico Metástase à distância  \
# 360524                   None           01/04/1996                  None
# 494715                   None           23/04/1993                  None
# 494716                   None           05/07/1993                  None
# 494717                   None           11/12/1993                  None
# 494718                   None           09/02/1993                  None
#
#        Regiao
# 360524    SUL
# 494715    SUL
# 494716    SUL
# 494717    SUL
# 494718    SUL
#
# [5 rows x 37 columns]

# %%
df.shape
# Out:
# (273439, 37)

# %%
df['Data de Diagnostico'].count()
# Out:
# 273439

# %%
df['Data de Diagnostico'] = pd.to_datetime(df['Data de Diagnostico'], format='%d/%m/%Y')

# %%
df['Data de Diagnostico'].count()
# Out:
# 273439

# %%
df = df.sort_values(by='Data de Diagnostico')

# %%
df.head()
# Out:
#              Nome do RCBP       Sexo Data de Nascimento  Idade  Raca/Cor  \
# 496900  RCBP PORTO ALEGRE   FEMININO         05/01/1947   45.0    BRANCO
# 495869  RCBP PORTO ALEGRE   FEMININO         18/11/1911   81.0    BRANCO
# 495267  RCBP PORTO ALEGRE   FEMININO         22/01/1950   42.0  INDÍGENA
# 496631  RCBP PORTO ALEGRE   FEMININO         28/10/1928   64.0    BRANCO
# 2155346  99 - SEM INFORMAÇÃO  999        MORTO        CÂNCER    31/12/2018
# 2154739                   99  999         VIVO          None          None
#
#         Data de Último Contato  Data de Diagnostico Metástase à distância  \
# 2158723             31/12/2018           2018-12-31                  None
# 2152236             31/12/2018           2018-12-31                  None
# 2159762             31/12/2018           2018-12-31                  None
# 2155346             31/12/2018           2018-12-31                  None
# 2154739             24/04/2019           2018-12-31                  None
#
#         Regiao
# 2158723    SUL
# 2152236    SUL
# 2159762    SUL
# 2155346    SUL
# 2154739    SUL
#
# [5 rows x 37 columns]

# %%
print(df['Data de Diagnostico'].min())
print(df['Data de Diagnostico'].max())
# Out:
# 1993-01-01 00:00:00
# 2018-12-31 00:00:00

# %%
datas = pd.date_range(start='1993-01-01', end='2018-12-31', freq='ME')
print(len(datas))
# Out:
# 312

# %%
n_unique_months = df['Data de Diagnostico'].dt.to_period('M').nunique()

print(n_unique_months)
# Out:
# 312

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 273439 entries, 496900 to 2154739
# Data columns (total 37 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Nome do RCBP                      273439 non-null  object
#  1   Sexo                              273439 non-null  object
#  2   Data de Nascimento                246437 non-null  object
#  3   Idade                             268267 non-null  float64
#  4   Raca/Cor                          273439 non-null  object
#  5   Nacionalidade                     268543 non-null  object
#  6   Naturalidade Estado               268597 non-null  object
#  7   Naturalidade                      102722 non-null  object
#  8   Grau de Instrução                 268539 non-null  object
#  9   Estado Civil                      264012 non-null  object
#  10  Código Profissão                  251484 non-null  float64
#  11  Nome Profissão                    251484 non-null  object
#  12  Estado Endereço                   273418 non-null  object
#  13  Cidade Endereço                   273439 non-null  object
#  14  Descrição da Topografia           273439 non-null  object
#  15  Código da Topografia              273439 non-null  object
#  16  Descrição da Morfologia           273439 non-null  object
#  17  Código da Morfologia              273439 non-null  float64
#  18  Descrição da Doenca               273439 non-null  object
#  19  Código da Doenca                  273439 non-null  object
#  20  Descrição da Doenca Infantil      3855 non-null    object
#  21  Código da Doenca Infantil         3855 non-null    object
#  22  Descrição da Doenca Adulto Jovem  7436 non-null    object
#  23  Código da Doenca Adulto Jovem     7436 non-null    object
#  24  Indicador de Caso Raro            273439 non-null  bool
#  25  Meio de Diagnostico               273439 non-null  object
#  26  Extensão                          273439 non-null  object
#  27  Lateralidade                      39322 non-null   object
#  28  Estadiamento                      273439 non-null  object
#  29  TNM                               273439 non-null  object
#  30  Status Vital                      68954 non-null   object
#  31  Tipo do Obito                     121480 non-null  object
#  32  Data do Óbito                     121480 non-null  object
#  33  Data de Último Contato            62755 non-null   object
#  34  Data de Diagnostico               273439 non-null  datetime64[ns]
#  35  Metástase à distância             1321 non-null    object
#  36  Regiao                            273439 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(3), object(32)
# memory usage: 77.4+ MB

# %% [markdown]
# # Verificação Temporal por Doença

# %%
df_mama = df[df['Descrição da Doenca'].isin(['MAMA , SOE', 'QUADRANTE SUPERIOR EXTERNO DA MAMA', 'PROLONGAMENTO AXILAR DA MAMA',
                                            'QUADRANTE SUPERIOR INTERNO DA MAMA', 'CARCINOMA "IN SITU" DA MAMA, SOE',
                                            'PORCAO CENTRAL DA MAMA', 'QUADRANTE INFERIOR EXTERNO DA MAMA',
                                            'LESAO INVASIVA DA MAMA', 'QUADRANTE INFERIOR INTERNO DA MAMA', 'MAMA'])]

df_prostata = df[df['Descrição da Doenca'] == 'PROSTATA']

df_colo_utero = df[df['Descrição da Doenca'].isin(['COLO DO UTERO, SOE', 'OUTRAS PARTES DO COLO DO UTERO',
                                                  'LESAO INVASIVA DO COLO DO UTERO', 'COLO DO UTERO',
                                                  'CARCINOMA "IN SITU" DO COLO DO UTERO (CERVIX)'])]

df_pele = df[df['Descrição da Doenca'].isin(['PELE DE OUTRAS PARTES DA FACE, SOE', 'PELE DE OUTRAS PARTES DA FACE',
                                            'PELE DO MEMBRO INFERIOR E DO QUADRIL','PELE DA PALPEBRA E CANTO',
                                            'PELE DO TRONCO','NEOPLASIA MALIGNA DA PELE','PELE DO COURO CABELUDO E DO PESCOCO',
                                            'PELE DA ORELHA E CONDUTO AUDITIVO EXTERNO','PELE DO MEMBRO SUPERIOR E DO OMBRO',
                                            'PELE DOS MEMBROS SUPERIORES, INCLUINDO OMBRO','PELE DO LABIO',
                                            'PELE DA ORELHA E DO CONDUTO AUDITIVO EXTERNO','SARCOMA DE KAPOSI DA PELE',
                                            'PELE DA PALPEBRA, INCLUINDO CANTO','PELE DOS MEMBROS INFERIORES, INCLUINDO QUADRIL',
                                            'MELANOMA MALIGNO DA PELE, SOE','PELE, SOE','LESAO INVASIVA DA PELE',
                                            'MELANOMA MALIGNO INVASIVO DA PELE','PELE DE OUTRAS LOCALIZACOES',
                                            'OUTRAS NEOPLASIAS MALIGNAS DA PELE'])]

df_pulmao = df[df['Descrição da Doenca'].isin(['BRONQUIOS OU PULMOES, SOE', 'BRONQUIOS E PULMOES',
                                              'LESAO INVASIVA DOS BRONQUIOS E DOS PULMOES'])]

# %%
df_mama = df_mama.sort_values(by='Data de Diagnostico')
df_prostata = df_prostata.sort_values(by='Data de Diagnostico')
df_colo_utero = df_colo_utero.sort_values(by='Data de Diagnostico')
df_pele = df_pele.sort_values(by='Data de Diagnostico')
df_pulmao = df_pulmao.sort_values(by='Data de Diagnostico')

# %%
df_mama = df_mama.set_index('Data de Diagnostico')
df_prostata = df_prostata.set_index('Data de Diagnostico')
df_colo_utero = df_colo_utero.set_index('Data de Diagnostico')
df_pele = df_pele.set_index('Data de Diagnostico')
df_pulmao = df_pulmao.set_index('Data de Diagnostico')

# %%
result_mama = df_mama.resample("ME")['Nome do RCBP'].count()
result_prostata = df_prostata.resample("ME")['Nome do RCBP'].count()
result_colo_utero = df_colo_utero.resample("ME")['Nome do RCBP'].count()
result_pele = df_pele.resample("ME")['Nome do RCBP'].count()
result_pulmao = df_pulmao.resample("ME")['Nome do RCBP'].count()

# %% [markdown]
# #### Mama

# %%
result_mama.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
acf_pacf(result_mama.values, 36)

# %% [markdown]
# #### Prostata

# %%
result_prostata.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
acf_pacf(result_prostata.values, 36)

# %% [markdown]
# #### Utero

# %%
result_colo_utero.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
acf_pacf(result_colo_utero.values, 36)

# %% [markdown]
# #### Pele

# %%
result_pele.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
acf_pacf(result_pele.values, 36)

# %% [markdown]
# #### Pulmao

# %%
result_pulmao.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
acf_pacf(result_pulmao.values, 36)
