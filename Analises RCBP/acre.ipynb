# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_acre = "../data/parquet/rcbp/RCBP ACRE.parquet"

df = pd.read_parquet(path_acre)

# %%
df.head()
# Out:
#         Nome do RCBP       Sexo Data de Nascimento  Idade        Raca/Cor  \
# 1198454    RCBP ACRE   FEMININO         27/04/1964   46.0           PARDA
# 1198455    RCBP ACRE  MASCULINO         26/08/1949   61.0  SEM INFORMAÇÃO
# 1198456    RCBP ACRE   FEMININO         25/04/1957   52.0           PARDA
# 1198457    RCBP ACRE   FEMININO         27/04/1962   48.0  SEM INFORMAÇÃO
# 1198458    RCBP ACRE   FEMININO         26/11/1967   42.0          BRANCO
#
#         Nacionalidade Naturalidade Estado Naturalidade  \
# 1198454        BRASIL  MATO GROSSO DO SUL         None
# 1198455        BRASIL                ACRE         None
# 1198456        BRASIL                ACRE         None
# 1198457        BRASIL                ACRE         None
# 1198458        BRASIL                ACRE         None
#
#                       Grau de Instrução    Estado Civil  ...        Extensão  \
# 1198454                  SEM INFORMAÇÃO          CASADO  ...  SEM INFORMAÇÃO
# 1198455  FUNDAMENTAL II (5ª A 8ª SÉRIE)          CASADO  ...   NÃO SE APLICA
# 1198456                  SEM INFORMAÇÃO          CASADO  ...      LOCALIZADO
# 1198457  FUNDAMENTAL II (5ª A 8ª SÉRIE)  SEM INFORMAÇÃO  ...  SEM INFORMAÇÃO
# 1198458                  SEM INFORMAÇÃO        SOLTEIRO  ...       METÁSTASE
#
#         Lateralidade Estadiamento  TNM    Status Vital   Tipo do Obito  \
# 1198454         None          nan  nan  SEM INFORMAÇÃO            None
# 1198455         None          nan  nan  SEM INFORMAÇÃO  SEM INFORMAÇÃO
# 1198456         None          nan  nan  SEM INFORMAÇÃO            None
# 1198457         None          nan  nan  SEM INFORMAÇÃO            None
# 1198458         None          nan  nan  SEM INFORMAÇÃO  SEM INFORMAÇÃO
#
#         Data do Óbito  Data de Último Contato Data de Diagnostico  \
# 1198454          None              06/10/2010          06/10/2010
# 1198455    14/03/2013              21/12/2010          15/12/2010
# 1198456          None              23/04/2010          10/02/2010
# 1198457          None              16/03/2011          21/10/2010
# 1198458    09/02/2012                    None          19/11/2010
#
#         Metástase à distância
# 1198454                  None
# 1198455                  None
# 1198456                  None
# 1198457                  None
# 1198458                  None
#
# [5 rows x 36 columns]

# %%
df.tail()
# Out:
#         Nome do RCBP       Sexo Data de Nascimento  Idade Raca/Cor  \
# 1833690    RCBP ACRE   FEMININO         05/07/1966   50.0    PARDA
# 1833691    RCBP ACRE   FEMININO         19/03/1969   48.0    PARDA
# 1833692    RCBP ACRE   FEMININO         02/02/1963   54.0    PARDA
# 1833693    RCBP ACRE   FEMININO         31/01/1941   76.0    PARDA
# 1833694    RCBP ACRE  MASCULINO         14/01/1982   35.0    PARDA
#
#         Nacionalidade Naturalidade Estado Naturalidade Grau de Instrução  \
# 1833690          None       Não informado         None              None
# 1833691          None                None         None              None
# 1833692          None                None         None              None
# 1833693          None                None         None              None
# 1833694          None                None         None              None
#
#         Estado Civil  ...        Extensão Lateralidade Estadiamento  TNM  \
# 1833690         None  ...  SEM INFORMAÇÃO         None          nan  nan
# 1833691         None  ...  SEM INFORMAÇÃO         None          nan  nan
# 1833692         None  ...  SEM INFORMAÇÃO         None          nan  nan
# 1833693         None  ...  SEM INFORMAÇÃO         None          nan  nan
# 1833694         None  ...  SEM INFORMAÇÃO         None          nan  nan
#
#         Status Vital Tipo do Obito Data do Óbito  Data de Último Contato  \
# 1833690         None          None          None                    None
# 1833691         None          None          None                    None
# 1833692         None          None          None                    None
# 1833693         None          None          None                    None
# 1833694         None        CÂNCER    15/08/2018                    None
#
#         Data de Diagnostico Metástase à distância
# 1833690          08/01/2017                  None
# 1833691          03/10/2017                  None
# 1833692          10/10/2017                  None
# 1833693          19/04/2017                  None
# 1833694          26/05/2017                  None
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6345 entries, 1198454 to 1833694
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Nome do RCBP                      6345 non-null   object
#  1   Sexo                              6345 non-null   object
#  2   Data de Nascimento                6343 non-null   object
#  3   Idade                             6345 non-null   float64
#  4   Raca/Cor                          6345 non-null   object
#  5   Nacionalidade                     5296 non-null   object
#  6   Naturalidade Estado               5760 non-null   object
#  7   Naturalidade                      109 non-null    object
#  8   Grau de Instrução                 5296 non-null   object
#  9   Estado Civil                      5295 non-null   object
#  10  Código Profissão                  5252 non-null   float64
#  11  Nome Profissão                    5252 non-null   object
#  12  Estado Endereço                   6345 non-null   object
#  13  Cidade Endereço                   6345 non-null   object
#  14  Descrição da Topografia           6345 non-null   object
#  15  Código da Topografia              6345 non-null   object
#  16  Descrição da Morfologia           6345 non-null   object
#  17  Código da Morfologia              6345 non-null   float64
#  18  Descrição da Doenca               6345 non-null   object
#  19  Código da Doenca                  6345 non-null   object
#  20  Descrição da Doenca Infantil      300 non-null    object
#  21  Código da Doenca Infantil         300 non-null    object
#  22  Descrição da Doenca Adulto Jovem  320 non-null    object
#  23  Código da Doenca Adulto Jovem     320 non-null    object
#  24  Indicador de Caso Raro            6345 non-null   bool
#  25  Meio de Diagnostico               6345 non-null   object
#  26  Extensão                          6345 non-null   object
#  27  Lateralidade                      2254 non-null   object
#  28  Estadiamento                      6345 non-null   object
#  29  TNM                               6345 non-null   object
#  30  Status Vital                      5293 non-null   object
#  31  Tipo do Obito                     3619 non-null   object
#  32  Data do Óbito                     3619 non-null   object
#  33  Data de Último Contato            4420 non-null   object
#  34  Data de Diagnostico               6345 non-null   object
#  35  Metástase à distância             0 non-null      object
# dtypes: bool(1), float64(3), object(32)
# memory usage: 1.7+ MB

# %%
df.shape
# Out:
# (6345, 36)

# %%
df['Data de Diagnostico'] = pd.to_datetime(df['Data de Diagnostico'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6345 entries, 1198454 to 1833694
# Data columns (total 36 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Nome do RCBP                      6345 non-null   object
#  1   Sexo                              6345 non-null   object
#  2   Data de Nascimento                6343 non-null   object
#  3   Idade                             6345 non-null   float64
#  4   Raca/Cor                          6345 non-null   object
#  5   Nacionalidade                     5296 non-null   object
#  6   Naturalidade Estado               5760 non-null   object
#  7   Naturalidade                      109 non-null    object
#  8   Grau de Instrução                 5296 non-null   object
#  9   Estado Civil                      5295 non-null   object
#  10  Código Profissão                  5252 non-null   float64
#  11  Nome Profissão                    5252 non-null   object
#  12  Estado Endereço                   6345 non-null   object
#  13  Cidade Endereço                   6345 non-null   object
#  14  Descrição da Topografia           6345 non-null   object
#  15  Código da Topografia              6345 non-null   object
#  16  Descrição da Morfologia           6345 non-null   object
#  17  Código da Morfologia              6345 non-null   float64
#  18  Descrição da Doenca               6345 non-null   object
#  19  Código da Doenca                  6345 non-null   object
#  20  Descrição da Doenca Infantil      300 non-null    object
#  21  Código da Doenca Infantil         300 non-null    object
#  22  Descrição da Doenca Adulto Jovem  320 non-null    object
#  23  Código da Doenca Adulto Jovem     320 non-null    object
#  24  Indicador de Caso Raro            6345 non-null   bool
#  25  Meio de Diagnostico               6345 non-null   object
#  26  Extensão                          6345 non-null   object
#  27  Lateralidade                      2254 non-null   object
#  28  Estadiamento                      6345 non-null   object
#  29  TNM                               6345 non-null   object
#  30  Status Vital                      5293 non-null   object
#  31  Tipo do Obito                     3619 non-null   object
#  32  Data do Óbito                     3619 non-null   object
#  33  Data de Último Contato            4420 non-null   object
#  34  Data de Diagnostico               6345 non-null   datetime64[ns]
#  35  Metástase à distância             0 non-null      object
# dtypes: bool(1), datetime64[ns](1), float64(3), object(31)
# memory usage: 1.7+ MB

# %%
print(df['Data de Diagnostico'].min())
print(df['Data de Diagnostico'].max())
# Out:
# 2010-01-02 00:00:00
# 2017-12-31 00:00:00

# %%
datas = pd.date_range(start='2010-01-02', end='2017-12-31', freq='ME')
print(len(datas))
# Out:
# 96

# %%
n_unique_months = df['Data de Diagnostico'].dt.to_period('M').nunique()
print(n_unique_months)
# Out:
# 96

# %%
df_mama = df[df['Descrição da Doenca'].isin(['MAMA , SOE', 'QUADRANTE SUPERIOR EXTERNO DA MAMA', 'PROLONGAMENTO AXILAR DA MAMA',
                                            'QUADRANTE SUPERIOR INTERNO DA MAMA', 'CARCINOMA "IN SITU" DA MAMA, SOE',
                                            'PORCAO CENTRAL DA MAMA', 'QUADRANTE INFERIOR EXTERNO DA MAMA',
                                            'LESAO INVASIVA DA MAMA', 'QUADRANTE INFERIOR INTERNO DA MAMA', 'MAMA'])]

df_prostata = df[df['Descrição da Doenca'] == 'PROSTATA']

df_colo_utero = df[df['Descrição da Doenca'].isin(['COLO DO UTERO, SOE', 'OUTRAS PARTES DO COLO DO UTERO',
                                                  'LESAO INVASIVA DO COLO DO UTERO', 'COLO DO UTERO',
                                                  'CARCINOMA "IN SITU" DO COLO DO UTERO (CERVIX)'])]

df_pele = df[df['Descrição da Doenca'].isin(['PELE DE OUTRAS PARTES DA FACE, SOE', 'PELE DE OUTRAS PARTES DA FACE',
                                            'PELE DO MEMBRO INFERIOR E DO QUADRIL','PELE DA PALPEBRA E CANTO',
                                            'PELE DO TRONCO','NEOPLASIA MALIGNA DA PELE','PELE DO COURO CABELUDO E DO PESCOCO',
                                            'PELE DA ORELHA E CONDUTO AUDITIVO EXTERNO','PELE DO MEMBRO SUPERIOR E DO OMBRO',
                                            'PELE DOS MEMBROS SUPERIORES, INCLUINDO OMBRO','PELE DO LABIO',
                                            'PELE DA ORELHA E DO CONDUTO AUDITIVO EXTERNO','SARCOMA DE KAPOSI DA PELE',
                                            'PELE DA PALPEBRA, INCLUINDO CANTO','PELE DOS MEMBROS INFERIORES, INCLUINDO QUADRIL',
                                            'MELANOMA MALIGNO DA PELE, SOE','PELE, SOE','LESAO INVASIVA DA PELE',
                                            'MELANOMA MALIGNO INVASIVO DA PELE','PELE DE OUTRAS LOCALIZACOES',
                                            'OUTRAS NEOPLASIAS MALIGNAS DA PELE'])]

df_pulmao = df[df['Descrição da Doenca'].isin(['BRONQUIOS OU PULMOES, SOE', 'BRONQUIOS E PULMOES',
                                              'LESAO INVASIVA DOS BRONQUIOS E DOS PULMOES'])]

# %%
df_mama = df_mama.sort_values(by='Data de Diagnostico')
df_mama = df_mama.set_index('Data de Diagnostico')
result_mama_acre = df_mama.resample("ME")['Nome do RCBP'].count()

result_mama_acre.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
df_prostata = df_prostata.sort_values(by='Data de Diagnostico')
df_prostata = df_prostata.set_index('Data de Diagnostico')
result_prostata_acre = df_prostata.resample("ME")['Nome do RCBP'].count()

result_prostata_acre.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
df_colo_utero = df_colo_utero.sort_values(by='Data de Diagnostico')
df_colo_utero = df_colo_utero.set_index('Data de Diagnostico')
result_colo_utero_acre = df_colo_utero.resample("ME")['Nome do RCBP'].count()

result_colo_utero_acre.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
df_pele = df_pele.sort_values(by='Data de Diagnostico')
df_pele = df_pele.set_index('Data de Diagnostico')
result_pele_acre = df_pele.resample("ME")['Nome do RCBP'].count()

result_pele_acre.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>

# %%
df_pulmao = df_pulmao.sort_values(by='Data de Diagnostico')
df_pulmao = df_pulmao.set_index('Data de Diagnostico')
result_pulmao_acre = df_pulmao.resample("ME")['Nome do RCBP'].count()

result_pulmao_acre.plot()
# Out:
# <Axes: xlabel='Data de Diagnostico'>
